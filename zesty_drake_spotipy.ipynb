# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import sys
sys.path.append(r'C:\Users\Sean\Documents\Python Testing\SpotifyTest')
import api_keys

client_id = api_keys.SPOTIFY_CLIENT_ID
client_secret = api_keys.SPOTIFY_CLIENT_SECRET
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
query = 'zesty drake'
result = sp.search(q=query, type='playlist', limit=1)

# %%
playlist_uri = result['playlists']['items'][0]['uri']
sp_playlist = sp.playlist_tracks(playlist_uri)

song_name = []
song_year = []
song_uri = []
song_album = []

for track_info in sp_playlist['items']:
    song_name.append(track_info['track']['name'])
    song_uri.append(track_info['track']['uri'])
    song_album.append(track_info['track']['album']['name'])
    song_year.append(track_info['track']['album']['release_date'].split('-')[0])

# %%
acoustic = []
dance = []
energy = []
instrumental = []
liveness = []
loudness = []
speech = []
tempo = []
valence = []
popularity = []

for i in song_uri:
    feat = sp.audio_features(i)[0]
    acoustic.append(feat['acousticness'])
    dance.append(feat['danceability'])
    energy.append(feat['energy'])
    speech.append(feat['speechiness'])
    instrumental.append(feat['instrumentalness'])
    loudness.append(feat['loudness'])
    tempo.append(feat['tempo'])
    liveness.append(feat['liveness'])
    valence.append(feat['valence'])
    popu = sp.track(i)
    popularity.append(popu['popularity'])

# %%
import pandas as pd
zesty_drake_df = pd.DataFrame({'name':song_name,
                        'album':song_album,
                        'year': song_year,
                        'dance':dance,
                        'acoustic':acoustic,
                        'energy':energy,
                        'instrumental':instrumental,
                        'liveness':liveness,
                        'loudness':loudness,
                        'speech':speech,
                        'tempo':tempo,
                        'valence':valence,
                        'popularity':popularity
                        })
zesty_drake_df
# Out:
#                                      name  \
# 0                               Rich Flex
# 1                            Falling Back
# 2                                Currents
# 3                         Calling My Name
# 4                                 Massive
# 5                         Flight's Booked
# 6        Girls Want Girls (with Lil Baby)
# 7   Way 2 Sexy (with Future & Young Thug)
# 8                            Toosie Slide
# 9          Pain 1993 (with Playboi Carti)
# 10                                  Jaded
# 11                 Ratchet Happy Birthday
# 12                         In My Feelings
# 13                          Teenage Fever
# 14                            Childs Play
# 15                                 Jungle
# 16                              From Time
# 17              Hold On, We're Going Home
# 18                            Shot For Me
# 19                              Take Care
# 20                           Feel No Ways
# ...

# %%
zesty_drake_df.to_csv('zesty_drake_discography.csv')
